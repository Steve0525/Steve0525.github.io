# %%
import pandas as pd
import numpy as np 
import ipywidgets 
import bqplot
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime as dt

# %% [markdown]
# ## Data preprocessing
#
# Read the dataset and clean the data.

# %%
building = pd.read_csv('building_inventory.csv',
                  na_values={'Congress Dist':0,
                            'Year Acquired':0,
                            'Square Footage':0})

# %% [markdown]
# First, check the value range of the columns and get the unique values for a basic exploration.

# %%
total_square=building.groupby('Year Acquired')['Square Footage'].sum()
total_square.index
# Out:
# Float64Index([1753.0, 1802.0, 1810.0, 1832.0, 1837.0, 1838.0, 1839.0, 1840.0,
#               1841.0, 1843.0,
#               ...
#               2010.0, 2011.0, 2012.0, 2013.0, 2014.0, 2015.0, 2016.0, 2017.0,
#               2018.0, 2019.0],
#              dtype='float64', name='Year Acquired', length=171)

# %%
agency = building['Agency Name'].unique()
agency
# Out:
# array(['Department of Natural Resources', 'Department of Corrections',
#        'Department of Human Services', 'Department of Transportation',
#        'Department of State Police', 'Department of Military Affairs',
#        'Department of Agriculture', 'Governors State University',
#        'Department of Central Management Services',
#        'Illinois State University', 'Historic Preservation Agency',
#        'Department of Juvenile Justice', 'Southern Illinois University',
#        'Illinois Medical District Commission', 'University of Illinois',
#        "Department of Veterans' Affairs", 'Chicago State University',
#        'Northern Illinois University', 'Office of the Secretary of State',
#        'Illinois Emergency Management Agency',
#        'Western Illinois University', 'Eastern Illinois University',
#        'Northeastern Illinois University',
#        'Illinois Community College Board',
#        'Illinois Board of Higher Education',
#        'IL State Board of Education', 'Department of Revenue',
#        "Governor's Office", 'Office of the Attorney General',
#        'Appellate Court / Fourth District', 'Department of Public Health',
#        'Illinois Courts', 'Appellate Court / Third District',
#        'Appellate Court / Fifth District',
#        'Appellate Court / Second District'], dtype=object)

# %%
con_dis = building['Congressional Full Name'].unique()
con_dis
# Out:
# array(['Cheri Bustos', 'John Shimkus', 'Adam Kinzinger',
#        'Darin M. LaHood', 'Bill Foster', 'Mike Bost',
#        'Daniel William Lipinski', 'Rodney L. Davis', 'Peter J. Roskam',
#        nan, 'Randy Hultgren', 'Danny K. Davis', 'Tammy Duckworth',
#        'Janice Schakowsky', 'Robin Kelly', 'Bobby L. Rush', 'Robert Dold',
#        'Mike Quigley', 'Luis Gutierrez'], dtype=object)

# %%
building_group = building.groupby(['Agency Name', 'Congressional Full Name'])['Square Footage'].sum()
building_group
# Out:
# Agency Name                        Congressional Full Name
# Appellate Court / Fifth District   Mike Bost                     15124.0
# Appellate Court / Fourth District  Rodney L. Davis               16400.0
# Appellate Court / Second District  Tammy Duckworth               43330.0
# Appellate Court / Third District   Adam Kinzinger                18700.0
# Chicago State University           Bobby L. Rush               1219492.0
#                                                                  ...
# University of Illinois             Danny K. Davis              6363904.0
#                                    Robin Kelly                 3643049.0
#                                    Rodney L. Davis            14695427.0
# Western Illinois University        Cheri Bustos                 385896.0
#                                    Darin M. LaHood             1962213.0
# Name: Square Footage, Length: 146, dtype: float64

# %% [markdown]
# ## Build the data matrix of ordinal data points
#
#
# I write this part by refering this website creating the pivot table. https://blog.algorexhealth.com/2017/09/10-heatmaps-10-python-libraries/
#
# To plot the ordinal data, first a matrix need to be constructed. This helps make the color scale for heatmap.

# %%
building_matrix = building.pivot_table(index = 'Agency Name', columns='Congressional Full Name', values = 'Square Footage',aggfunc = sum)
building_matrix
# Out:
# Congressional Full Name                    Adam Kinzinger  Bill Foster  \
# Agency Name
# Appellate Court / Fifth District                      NaN          NaN
# Appellate Court / Fourth District                     NaN          NaN
# Appellate Court / Second District                     NaN          NaN
# Appellate Court / Third District                  18700.0          NaN
# Chicago State University                              NaN          NaN
# Department of Agriculture                             NaN          NaN
# Department of Central Management Services         44130.0          NaN
# Department of Corrections                       2862863.0    2598339.0
# Department of Human Services                     206088.0      66673.0
# Department of Juvenile Justice                        NaN          NaN
# Department of Military Affairs                   342638.0      54012.0
# Department of Natural Resources                  577616.0          NaN
# Department of Public Health                           NaN          NaN
# Department of Revenue                                 NaN          NaN
# Department of State Police                        40242.0      30914.0
# Department of Transportation                     738336.0      73072.0
# Department of Veterans' Affairs                  124235.0          NaN
# Eastern Illinois University                           NaN          NaN
# Governor's Office                                     NaN          NaN
# Governors State University                            NaN          NaN
# Historic Preservation Agency                      11700.0          NaN
# IL State Board of Education                           NaN          NaN
# Illinois Board of Higher Education                    NaN     545816.0
# Illinois Community College Board                  49552.0      99068.0
# Illinois Courts                                       NaN          NaN
# Illinois Emergency Management Agency                  NaN          NaN
# Illinois Medical District Commission                  NaN          NaN
# Illinois State University                             NaN          NaN
# Northeastern Illinois University                      NaN          NaN
# Northern Illinois University                    3709780.0          NaN
# Office of the Attorney General                        NaN          NaN
# Office of the Secretary of State                      NaN          NaN
# Southern Illinois University                          NaN          NaN
# University of Illinois                                NaN          NaN
# Western Illinois University                           NaN          NaN
#
# Congressional Full Name                    Bobby L. Rush  Cheri Bustos  \
# Agency Name
# Appellate Court / Fifth District                     NaN           NaN
# Appellate Court / Fourth District                    NaN           NaN
# Appellate Court / Second District                    NaN           NaN
# Appellate Court / Third District                     NaN           NaN
# Chicago State University                       1219492.0           NaN
# Department of Agriculture                            NaN       29350.0
# Department of Central Management Services            NaN      151963.0
# Department of Corrections                            NaN     1518546.0
# Department of Human Services                    449547.0      247839.0
# Department of Juvenile Justice                       NaN      227480.0
# Department of Military Affairs                  564580.0      386238.0
# Department of Natural Resources                      NaN      402882.0
# Department of Public Health                          NaN           NaN
# Department of Revenue                                NaN           NaN
# Department of State Police                           NaN       50974.0
# Department of Transportation                    118143.0      430972.0
# Department of Veterans' Affairs                      NaN           NaN
# Eastern Illinois University                          NaN           NaN
# Governor's Office                                    NaN           NaN
# Governors State University                           NaN           NaN
# Historic Preservation Agency                         NaN      112777.0
# IL State Board of Education                          NaN           NaN
# Illinois Board of Higher Education                   NaN           NaN
# Illinois Community College Board                     NaN       26700.0
# Illinois Courts                                      NaN           NaN
# Illinois Emergency Management Agency                 NaN           NaN
# Illinois Medical District Commission                 NaN           NaN
# Illinois State University                            NaN           NaN
# Northeastern Illinois University                     NaN           NaN
# Northern Illinois University                         NaN           NaN
# Office of the Attorney General                       NaN       60500.0
# Office of the Secretary of State                     NaN           NaN
# Southern Illinois University                         NaN           NaN
# University of Illinois                               NaN      315626.0
# Western Illinois University                          NaN      385896.0
#
# Congressional Full Name                    Daniel William Lipinski  \
# Agency Name
# Appellate Court / Fifth District                               NaN
# Appellate Court / Fourth District                              NaN
# Appellate Court / Second District                              NaN
# Appellate Court / Third District                               NaN
# Chicago State University                                       NaN
# Department of Agriculture                                      NaN
# Department of Central Management Services                      NaN
# Department of Corrections                                      NaN
# Department of Human Services                                   NaN
# Department of Juvenile Justice                                 NaN
# Department of Military Affairs                             48552.0
# Department of Natural Resources                                NaN
# Department of Public Health                                    NaN
# Department of Revenue                                          NaN
# Department of State Police                                 14583.0
# Department of Transportation                              132581.0
# Department of Veterans' Affairs                                NaN
# Eastern Illinois University                                    NaN
# Governor's Office                                              NaN
# Governors State University                               1055971.0
# Historic Preservation Agency                                   NaN
# IL State Board of Education                                    NaN
# Illinois Board of Higher Education                             NaN
# Illinois Community College Board                           42000.0
# Illinois Courts                                                NaN
# Illinois Emergency Management Agency                           NaN
# Illinois Medical District Commission                           NaN
# Illinois State University                                      NaN
# Northeastern Illinois University                               NaN
# Northern Illinois University                                   NaN
# Office of the Attorney General                                 NaN
# Office of the Secretary of State                               NaN
# Southern Illinois University                                   NaN
# University of Illinois                                         NaN
# Western Illinois University                                    NaN
#
# Congressional Full Name                    Danny K. Davis  Darin M. LaHood  \
# Agency Name
# Appellate Court / Fifth District                      NaN              NaN
# Appellate Court / Fourth District                     NaN              NaN
# Appellate Court / Second District                     NaN              NaN
# Appellate Court / Third District                      NaN              NaN
# Chicago State University                              NaN              NaN
# Department of Agriculture                             NaN              NaN
# Department of Central Management Services       2088840.0          54014.0
# Department of Corrections                             NaN        1656696.0
# Department of Human Services                     304039.0        1887569.0
# Department of Juvenile Justice                        NaN              NaN
# Department of Military Affairs                   240400.0         138062.0
# Department of Natural Resources                       NaN         656403.0
# Department of Public Health                           NaN              NaN
# Department of Revenue                                 NaN              NaN
# Department of State Police                        85708.0         169155.0
# Department of Transportation                      54492.0         516516.0
# Department of Veterans' Affairs                       NaN         652160.0
# Eastern Illinois University                           NaN              NaN
# Governor's Office                                     NaN              NaN
# Governors State University                            NaN              NaN
# Historic Preservation Agency                       2364.0         175427.0
# IL State Board of Education                           NaN              NaN
# Illinois Board of Higher Education                    NaN              NaN
# Illinois Community College Board                      NaN         252623.0
# Illinois Courts                                       NaN              NaN
# Illinois Emergency Management Agency                  NaN              NaN
# Illinois Medical District Commission              15000.0              NaN
# Illinois State University                             NaN              NaN
# Northeastern Illinois University                      NaN              NaN
# Northern Illinois University                          NaN              NaN
# Office of the Attorney General                        NaN              NaN
# Office of the Secretary of State                  56904.0              NaN
# Southern Illinois University                          NaN              NaN
# University of Illinois                          6363904.0              NaN
# Western Illinois University                           NaN        1962213.0
#
# Congressional Full Name                    Janice Schakowsky  John Shimkus  \
# Agency Name
# Appellate Court / Fifth District                         NaN           NaN
# Appellate Court / Fourth District                        NaN           NaN
# Appellate Court / Second District                        NaN           NaN
# Appellate Court / Third District                         NaN           NaN
# Chicago State University                                 NaN           NaN
# Department of Agriculture                                NaN       41984.0
# Department of Central Management Services                NaN       70160.0
# Department of Corrections                                NaN     2908649.0
# Department of Human Services                             NaN      394598.0
# Department of Juvenile Justice                           NaN      209238.0
# Department of Military Affairs                           NaN      882286.0
# Department of Natural Resources                       8228.0      574690.0
# Department of Public Health                              NaN           NaN
# Department of Revenue                                    NaN           NaN
# Department of State Police                               NaN       26710.0
# Department of Transportation                         69750.0      838934.0
# Department of Veterans' Affairs                          NaN           NaN
# Eastern Illinois University                              NaN     1164674.0
# Governor's Office                                        NaN           NaN
# Governors State University                               NaN           NaN
# Historic Preservation Agency                             NaN       98011.0
# IL State Board of Education                              NaN           NaN
# Illinois Board of Higher Education                       NaN           NaN
# Illinois Community College Board                         NaN           NaN
# Illinois Courts                                          NaN           NaN
# Illinois Emergency Management Agency                     NaN           NaN
# Illinois Medical District Commission                     NaN           NaN
# Illinois State University                                NaN           NaN
# Northeastern Illinois University                         NaN           NaN
# Northern Illinois University                             NaN           NaN
# Office of the Attorney General                           NaN           NaN
# Office of the Secretary of State                         NaN           NaN
# Southern Illinois University                             NaN           NaN
# University of Illinois                                   NaN           NaN
# Western Illinois University                              NaN           NaN
#
# Congressional Full Name                    Luis Gutierrez  Mike Bost  \
# Agency Name
# Appellate Court / Fifth District                      NaN    15124.0
# Appellate Court / Fourth District                     NaN        NaN
# Appellate Court / Second District                     NaN        NaN
# Appellate Court / Third District                      NaN        NaN
# Chicago State University                              NaN        NaN
# Department of Agriculture                             NaN   536232.0
# Department of Central Management Services             NaN    98355.0
# Department of Corrections                             NaN  2594507.0
# Department of Human Services                          NaN  1579965.0
# Department of Juvenile Justice                        NaN    63508.0
# Department of Military Affairs                   224959.0   426121.0
# Department of Natural Resources                       NaN   649139.0
# Department of Public Health                           NaN     7160.0
# Department of Revenue                                 NaN        NaN
# Department of State Police                            NaN   113685.0
# Department of Transportation                      34982.0   638311.0
# Department of Veterans' Affairs                       NaN    40000.0
# Eastern Illinois University                           NaN        NaN
# Governor's Office                                     NaN        NaN
# Governors State University                            NaN        NaN
# Historic Preservation Agency                      57800.0   123924.0
# IL State Board of Education                           NaN        NaN
# Illinois Board of Higher Education                    NaN        NaN
# Illinois Community College Board                      NaN        NaN
# Illinois Courts                                       NaN        NaN
# Illinois Emergency Management Agency                  NaN        NaN
# Illinois Medical District Commission                  NaN        NaN
# Illinois State University                             NaN        NaN
# Northeastern Illinois University                      NaN        NaN
# Northern Illinois University                          NaN        NaN
# Office of the Attorney General                        NaN        NaN
# Office of the Secretary of State                      NaN        NaN
# Southern Illinois University                          NaN  5558744.0
# University of Illinois                                NaN        NaN
# Western Illinois University                           NaN        NaN
#
# Congressional Full Name                    Mike Quigley  Peter J. Roskam  \
# Agency Name
# Appellate Court / Fifth District                    NaN              NaN
# Appellate Court / Fourth District                   NaN              NaN
# Appellate Court / Second District                   NaN              NaN
# Appellate Court / Third District                    NaN              NaN
# Chicago State University                            NaN              NaN
# Department of Agriculture                           NaN              NaN
# Department of Central Management Services        9932.0              NaN
# Department of Corrections                           NaN              NaN
# Department of Human Services                   362890.0              NaN
# Department of Juvenile Justice                      NaN          72411.0
# Department of Military Affairs                      NaN              NaN
# Department of Natural Resources                     NaN          24105.0
# Department of Public Health                         NaN              NaN
# Department of Revenue                               NaN              NaN
# Department of State Police                          NaN              NaN
# Department of Transportation                   112120.0          29996.0
# Department of Veterans' Affairs                185525.0              NaN
# Eastern Illinois University                         NaN              NaN
# Governor's Office                                   NaN              NaN
# Governors State University                          NaN              NaN
# Historic Preservation Agency                        NaN              NaN
# IL State Board of Education                         NaN          19147.0
# Illinois Board of Higher Education                  NaN              NaN
# Illinois Community College Board                    NaN              NaN
# Illinois Courts                                     NaN              NaN
# Illinois Emergency Management Agency                NaN              NaN
# Illinois Medical District Commission                NaN              NaN
# Illinois State University                           NaN              NaN
# Northeastern Illinois University              1110103.0              NaN
# Northern Illinois University                        NaN              NaN
# Office of the Attorney General                      NaN              NaN
# Office of the Secretary of State                28452.0              NaN
# Southern Illinois University                        NaN              NaN
# University of Illinois                              NaN              NaN
# Western Illinois University                         NaN              NaN
#
# Congressional Full Name                    Randy Hultgren  Robert Dold  \
# Agency Name
# Appellate Court / Fifth District                      NaN          NaN
# Appellate Court / Fourth District                     NaN          NaN
# Appellate Court / Second District                     NaN          NaN
# Appellate Court / Third District                      NaN          NaN
# Chicago State University                              NaN          NaN
# Department of Agriculture                             NaN          NaN
# Department of Central Management Services             NaN     443865.0
# Department of Corrections                             NaN          NaN
# Department of Human Services                          NaN     234642.0
# Department of Juvenile Justice                   538807.0          NaN
# Department of Military Affairs                    52366.0      40852.0
# Department of Natural Resources                  173515.0     200392.0
# Department of Public Health                           NaN          NaN
# Department of Revenue                                 NaN          NaN
# Department of State Police                            NaN       6246.0
# Department of Transportation                      92420.0       3270.0
# Department of Veterans' Affairs                       NaN          NaN
# Eastern Illinois University                           NaN          NaN
# Governor's Office                                     NaN          NaN
# Governors State University                            NaN          NaN
# Historic Preservation Agency                          NaN          NaN
# IL State Board of Education                           NaN          NaN
# Illinois Board of Higher Education                    NaN          NaN
# Illinois Community College Board                      NaN          NaN
# Illinois Courts                                       NaN          NaN
# Illinois Emergency Management Agency                  NaN          NaN
# Illinois Medical District Commission                  NaN          NaN
# Illinois State University                             NaN          NaN
# Northeastern Illinois University                      NaN          NaN
# Northern Illinois University                          NaN          NaN
# Office of the Attorney General                        NaN          NaN
# Office of the Secretary of State                      NaN          NaN
# Southern Illinois University                          NaN          NaN
# University of Illinois                                NaN          NaN
# Western Illinois University                           NaN          NaN
#
# Congressional Full Name                    Robin Kelly  Rodney L. Davis  \
# Agency Name
# Appellate Court / Fifth District                   NaN              NaN
# Appellate Court / Fourth District                  NaN          16400.0
# Appellate Court / Second District                  NaN              NaN
# Appellate Court / Third District                   NaN              NaN
# Chicago State University                           NaN              NaN
# Department of Agriculture                          NaN        2000832.0
# Department of Central Management Services          NaN        1003106.0
# Department of Corrections                      49572.0         931578.0
# Department of Human Services                 1253943.0         192934.0
# Department of Juvenile Justice                     NaN          36538.0
# Department of Military Affairs                226500.0         920736.0
# Department of Natural Resources                59050.0         571050.0
# Department of Public Health                        NaN              NaN
# Department of Revenue                              NaN         913236.0
# Department of State Police                         NaN         272619.0
# Department of Transportation                  287509.0        1034012.0
# Department of Veterans' Affairs               479061.0              NaN
# Eastern Illinois University                        NaN              NaN
# Governor's Office                                  NaN          45120.0
# Governors State University                         NaN              NaN
# Historic Preservation Agency                  287000.0         795120.0
# IL State Board of Education                        NaN              NaN
# Illinois Board of Higher Education                 NaN              NaN
# Illinois Community College Board                   NaN          16530.0
# Illinois Courts                                    NaN          54540.0
# Illinois Emergency Management Agency               NaN          50000.0
# Illinois Medical District Commission               NaN              NaN
# Illinois State University                          NaN        2960272.0
# Northeastern Illinois University                   NaN              NaN
# Northern Illinois University                       NaN              NaN
# Office of the Attorney General                     NaN              NaN
# Office of the Secretary of State                   NaN        2188472.0
# Southern Illinois University                       NaN        3150729.0
# University of Illinois                       3643049.0       14695427.0
# Western Illinois University                        NaN              NaN
#
# Congressional Full Name                    Tammy Duckworth
# Agency Name
# Appellate Court / Fifth District                       NaN
# Appellate Court / Fourth District                      NaN
# Appellate Court / Second District                  43330.0
# Appellate Court / Third District                       NaN
# Chicago State University                               NaN
# Department of Agriculture                              NaN
# Department of Central Management Services          65268.0
# Department of Corrections                              NaN
# Department of Human Services                      913263.0
# Department of Juvenile Justice                         NaN
# Department of Military Affairs                     31168.0
# Department of Natural Resources                        NaN
# Department of Public Health                            NaN
# Department of Revenue                                  NaN
# Department of State Police                          9776.0
# Department of Transportation                      398743.0
# Department of Veterans' Affairs                        NaN
# Eastern Illinois University                            NaN
# Governor's Office                                      NaN
# Governors State University                             NaN
# Historic Preservation Agency                           NaN
# IL State Board of Education                            NaN
# Illinois Board of Higher Education                     NaN
# Illinois Community College Board                       NaN
# Illinois Courts                                        NaN
# Illinois Emergency Management Agency                   NaN
# Illinois Medical District Commission                   NaN
# Illinois State University                              NaN
# Northeastern Illinois University                       NaN
# Northern Illinois University                           NaN
# Office of the Attorney General                         NaN
# Office of the Secretary of State                       NaN
# Southern Illinois University                           NaN
# University of Illinois                                 NaN
# Western Illinois University                            NaN

# %% [markdown]
# ## Grid heatmap
#
# This is to test whether the heatmap works well and plot the result needed. And I tried to solve the problem of no enough space to show the lables.
#
# One problem for the plot is that, I didn't find out the way to show the whole labels of x and y. And the y axis labels and legend labels  could be seen by setting the figure margins.

# %%
# x and y data
x = building_matrix.index
y = building_matrix.columns

# scales 
x_sc = bqplot.OrdinalScale()
y_sc = bqplot.OrdinalScale()
col_sc = bqplot.ColorScale(schema='RdPu')

# axis 
x_ax = bqplot.Axis(scale=x_sc, label='Agency Name', tick_rotate = 90,  tick_style = {'font-size': 8})
y_ax = bqplot.Axis(scale=y_sc, label='Congress Dist', orientation='vertical',  tick_style = {'font-size': 8})
c_ax = bqplot.ColorAxis(scale = col_sc, orientation='vertical', side='right')

# marks
heat_map = bqplot.GridHeatMap(color= building_matrix, 
                              row= x.tolist(), 
                              column= y.tolist(),
                             scales = {'color':col_sc, 'row':y_sc, 'column':x_sc},
                             interactions={'click':'select'},
                             anchor_style={'fill':'blue'})
# interactivity
mySelectedLable = ipywidgets.Label()# print out info about our selection 

def get_data_value(change):
    # to make sure we only support single selections 
    if len(change['owner'].selected) == 1: # only one selection
        
        i,j = change['owner'].selected[0]
        v = building_matrix.iloc[i, j] 
        mySelectedLable.value = 'Total Square Footage(sft)=' + str(v)
        print(building_matrix.index[i])
        print(building_matrix.columns[j])
        
heat_map.observe(get_data_value, 'selected')
# put all together
fig = bqplot.Figure(marks=[heat_map], axes = [c_ax, y_ax, x_ax], fig_margin={'top':60, 'bottom':100, 'left':150, 'right':100})
fig.layout.max_width = '600px'
fig.layout.min_height = '800px'

myDashboard = ipywidgets.VBox([mySelectedLable, fig])
myDashboard
# Out:
# VBox(children=(Label(value=''), Figure(axes=[ColorAxis(orientation='vertical', scale=ColorScale(), side='right…

# %% [markdown]
# # line plot

# %%
heat_map.keys
# Out:
# ['_model_module',
#  '_model_module_version',
#  '_model_name',
#  '_view_count',
#  '_view_module',
#  '_view_module_version',
#  '_view_name',
#  'anchor_style',
#  'apply_clip',
#  'color',
#  'column',
#  'column_align',
#  'display_format',
#  'display_legend',
#  'enable_hover',
#  'font_style',
#  'interactions',
#  'labels',
#  'null_color',
#  'opacity',
#  'preserve_domain',
#  'row',
#  'row_align',
#  'scales',
#  'scales_metadata',
#  'selected',
#  'selected_style',
#  'stroke',
#  'tooltip',
#  'tooltip_location',
#  'tooltip_style',
#  'unselected_style',
#  'visible']

# %%
# create plot elemetns 
x_scl = bqplot.LinearScale()
y_scl = bqplot.LogScale() # since we know duration is best shown in log

ax_xcl = bqplot.Axis(label='Year Acquired', scale=x_scl) # dates
ax_ycl = bqplot.Axis(label='Total Square Footage', scale=y_scl,
                     orientation='vertical', side='left')

line = bqplot.Lines(x= total_square.index,
                   y = total_square,
                   scales = {'x':x_scl, 'y':y_scl})

# figure 
fig = bqplot.Figure(axes=[ax_xcl, ax_ycl], marks=[line])
fig
# Out:
# Figure(axes=[Axis(label='Year Acquired', scale=LinearScale()), Axis(label='Total Square Footage', orientation=…

# %% [markdown]
# # Add interactivity

# %%
# CRATE LABEL - # 1
mySelectedLable = ipywidgets.Label()# print out info about our selection

# %%
# create heatmap elements
# x and y data
x = building_matrix.index
y = building_matrix.columns

# scales 
x_sc = bqplot.OrdinalScale()
y_sc = bqplot.OrdinalScale()
col_sc = bqplot.ColorScale(schema='BuPu')

# axis, remember to rotate the x value 
x_ax = bqplot.Axis(scale=x_sc, label='Agency Name', tick_rotate = 90,  tick_style = {'font-size': 8})
y_ax = bqplot.Axis(scale=y_sc, label='Congress Dist', orientation='vertical',  tick_style = {'font-size': 8})
c_ax = bqplot.ColorAxis(scale = col_sc, orientation='vertical', side='right',)

# marks
heat_map = bqplot.GridHeatMap(color= building_matrix, 
                              row= x.tolist(), 
                              column= y.tolist(),
                             scales = {'color':col_sc, 'row':y_sc, 'column':x_sc},
                             interactions={'click':'select'},
                             anchor_style={'fill':'blue'},
                             fig_margin={'top':20, 'bottom':100, 'left':1000, 'right':20})

# %%
# create plot elemetns 
x_scl = bqplot.LinearScale()
y_scl = bqplot.LogScale() # for many agency the total square footage are in huge difference in different time

# axis 
ax_xcl = bqplot.Axis(label='Year Acquired', scale=x_scl, tick_rotate = 90,  tick_style = {'font-size': 8}) # dates
ax_ycl = bqplot.Axis(label='Total Square Footage', scale=y_scl,
                     orientation='vertical', side='left',  tick_style = {'font-size': 8})
# mark
line = bqplot.Lines(x= total_square.index,
                   y = total_square,
                   scales = {'x':x_scl, 'y':y_scl})

# figure 
fig = bqplot.Figure(axes=[ax_xcl, ax_ycl], marks=[line])

# %%
# link lineplot with heatmap 
def get_data_value(change):
    # to make sure we only support single selections 
    if len(change['owner'].selected) == 1: # only one selection
        
        i,j = change['owner'].selected[0]
        v = building_matrix.iloc[i, j] 
        
        mySelectedLable.value = 'Total Square Footage(sft)=' + str(v)
#         print(building_matrix.index[i])
#         print(building_matrix.columns[j])
        
        # get the value of the corresponding agency name and congresstional district name 
        agency = building_matrix.index[i]
        congress = building_matrix.columns[j]
        
        df_square = building[(building['Agency Name']== agency) & (building['Congressional Full Name']== congress)]
        total_square = df_square.groupby('Year Acquired')['Square Footage'].sum()
        
        line.x = total_square.index
        line.y = total_square
        
        
# make sure to observe the change         
heat_map.observe(get_data_value, 'selected')
# put all together
fig = bqplot.Figure(marks=[heat_map], axes = [c_ax, y_ax, x_ax], )

# %%
# create figure objects
fig_heatmap = bqplot.Figure(marks=[heat_map], axes = [c_ax, y_ax, x_ax],fig_margin={'top':20, 'bottom':100, 'left':150, 'right':100})
fig_line = bqplot.Figure(marks=[line], axes = [ax_xcl, ax_ycl],fig_margin={'top':20, 'bottom':100, 'left':60, 'right':60})

# %%
# put it all together finally ! as a dashboard
fig_heatmap.layout.min_width = '500px'
fig_line.layout.min_width = '500px'
plots = ipywidgets.HBox([fig_heatmap, fig_line])
myDashboard = ipywidgets.VBox([mySelectedLable, plots])

myDashboard
# Out:
# VBox(children=(Label(value='Total Square Footage(sft)=516516.0'), HBox(children=(Figure(axes=[ColorAxis(orient…

# %% [markdown]
# A strange thing happens when I change the cells, maybe after 7 to 8 times, the line plot does not refresh. Don't know why. No warnings or any error raised.
#
# And also, the labels at bottom is still incomplete,
#
# The two problems are  still not solved when submitted.

# %% [markdown]
# ## Things to think about
#
# * Can you keep the x and y ranges static on the line plot?
#
#     I believe it can be set a fixed range on the x and y axis but haven't figure it out.
#
#
# * Can you change the style?
#     I find out that it's hard to change the margins or other parameters to show the labels of each axis. But there is a parameter for line plot called line_style, so the style can be changed.
